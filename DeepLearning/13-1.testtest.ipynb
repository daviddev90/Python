# %%
from PIL import Image
import numpy as np
import glob
import csv

# %%
# 빈 Numpy 배열이 있어야 함
chairData = np.zeros(60* 360*360, dtype=np.int32).reshape(60, 360, 360)
laptopData = np.zeros(60*360*360, dtype=np.int32).reshape(60, 360, 360)
pianoData = np.zeros(60*360*360, dtype=np.int32).reshape(60, 360, 360)

i = 0
for filename in sorted(glob.glob('data/cnn_processed/chair/*.jpg')):
  img = np.array(Image.open(filename), dtype=np.int32)
  chairData[i,:,:] = img
  i += 1

i = 0
for filename in sorted(glob.glob('data/cnn_processed/laptop/*.jpg')):
  img = np.array(Image.open(filename), dtype=np.int32)
  laptopData[i,:,:] = img
  i += 1

i = 0
for filename in sorted(glob.glob('data/cnn_processed/piano/*.jpg')):
  img = np.array(Image.open(filename), dtype=np.int32)
  pianoData[i,:,:] = img
  i += 1
print(pianoData.shape)
# Out:
# (60, 360, 360)

# %%
train = np.concatenate((chairData, laptopData, pianoData), axis=0)
train = train.reshape(train.shape[0], train.shape[1], train.shape[2], 1) / 255
target = np.concatenate((np.zeros(60), np.ones(60), np.full(60, 2)), axis=0)

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.2)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2)

print('X_train.shape:', X_train.shape)
print('X_valid.shape:', X_valid.shape)
print('X_test.shape:', X_test.shape)
print('y_train.shape:', y_train.shape)
print('y_valid.shape:', y_valid.shape)
print('y_test.shape:', y_test.shape)
# Out:
# X_train.shape: (115, 360, 360, 1)
# X_valid.shape: (29, 360, 360, 1)
# X_test.shape: (36, 360, 360, 1)
# y_train.shape: (115,)
# y_valid.shape: (29,)
# y_test.shape: (36,)

# %% [markdown]
# # model 만들기

# %%
modelCharacters = []
idx = 0

# 처음 들어가는 filter 갯수 조절
for i in [32, 64]:
  # 은닉층 갯수 조절
  for j in range(2):
    for _ in range(j+1):
      for bool in [ True, False ]:
          # for k in [0.2, 0.25, 0.3]:
            model = keras.Sequential()
            model.add(keras.layers.Conv2D(i, (3, 3), padding='same', input_shape=(360, 360, 1)))

            if bool:
              model.add(keras.layers.Conv2D(i, (3, 3), padding='same'))
            else:
              model.add(keras.layers.Conv2D(i, (5, 5), padding='same'))

            model.add(keras.layers.MaxPooling2D((2, 2)))
            
            model.add(keras.layers.Dropout(0.25))

            model.add(keras.layers.Flatten())
            model.add(keras.layers.Dense(i, activation='relu'))
            model.add(keras.layers.Dense(3, activation='softmax'))


            # 모델 컴파일
            model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

            checkpoint_cb = keras.callbacks.ModelCheckpoint(
                'results/cnn1/res'+str(idx)+'.h5',
                monitor='val_loss',
                verbose=1,
                save_best_only=True,
                mode='min'
            )
            history = model.fit(
                X_train,
                y_train,
                epochs=20,
                validation_data=(X_valid, y_valid),
                callbacks=[checkpoint_cb]
            )
            # read best model
            model = keras.models.load_model('results/cnn1/res'+str(idx)+'.h5')

            # test 데이터로 평가
            test_loss, test_acc = model.evaluate(X_test, y_test)
            print('test_loss:', test_loss)
            print('test_acc:', test_acc)

            modelCharacter = {
              'idx': idx,
              'numberOfFilters': i,
              'numberOfLayers': j+1,
              'padding3': bool,
              'dropoutRatio': k,
              'test_loss': test_loss,
              'test_acc': test_acc
            }
            modelCharacters.append(modelCharacter)
            idx += 1

            with open('results/cnn_modelCharacters.csv', 'w', newline='') as f:
              writer = csv.writer(f)
              writer.writerow(['idx', 'numberOfFilters', 'numberOfLayers', 'padding3', 'dropoutRatio', 'test_loss', 'test_acc'])
              for modelCharacter in modelCharacters:
                writer.writerow([modelCharacter['idx'], modelCharacter['numberOfFilters'], modelCharacter['numberOfLayers'], modelCharacter['padding3'], modelCharacter['dropoutRatio'], modelCharacter['test_loss'], modelCharacter['test_acc']])
    

# save modelCharacters as csv
# Out:
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 20.5395 - accuracy: 0.3217
# Epoch 1: val_loss improved from inf to 7.09277, saving model to results/cnn1/res0.h5
# 4/4 [==============================] - 23s 6s/step - loss: 20.5395 - accuracy: 0.3217 - val_loss: 7.0928 - val_accuracy: 0.5517
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 5.0315 - accuracy: 0.5565
# Epoch 2: val_loss improved from 7.09277 to 3.31649, saving model to results/cnn1/res0.h5
# 4/4 [==============================] - 23s 6s/step - loss: 5.0315 - accuracy: 0.5565 - val_loss: 3.3165 - val_accuracy: 0.6207
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 7.4644 - accuracy: 0.4522
# Epoch 3: val_loss improved from 3.31649 to 1.80341, saving model to results/cnn1/res0.h5
# 4/4 [==============================] - 20s 5s/step - loss: 7.4644 - accuracy: 0.4522 - val_loss: 1.8034 - val_accuracy: 0.6897
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 1.7229 - accuracy: 0.7826
# Epoch 4: val_loss did not improve from 1.80341
# 4/4 [==============================] - 16s 4s/step - loss: 1.7229 - accuracy: 0.7826 - val_loss: 2.5483 - val_accuracy: 0.7931
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 2.6517 - accuracy: 0.7739
# Epoch 5: val_loss did not improve from 1.80341
# 4/4 [==============================] - 16s 4s/step - loss: 2.6517 - accuracy: 0.7739 - val_loss: 2.8473 - val_accuracy: 0.8276
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 1.8051 - accuracy: 0.8522
# Epoch 6: val_loss did not improve from 1.80341
# 4/4 [==============================] - 15s 4s/step - loss: 1.8051 - accuracy: 0.8522 - val_loss: 1.8817 - val_accuracy: 0.8621
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 1.3060 - accuracy: 0.8435
# Epoch 7: val_loss did not improve from 1.80341
# 4/4 [==============================] - 16s 4s/step - loss: 1.3060 - accuracy: 0.8435 - val_loss: 1.8773 - val_accuracy: 0.7931
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.9270 - accuracy: 0.8348
# Epoch 8: val_loss did not improve from 1.80341
# 4/4 [==============================] - 16s 4s/step - loss: 0.9270 - accuracy: 0.8348 - val_loss: 2.3243 - val_accuracy: 0.7586
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6753 - accuracy: 0.8870
# Epoch 9: val_loss did not improve from 1.80341
# 4/4 [==============================] - 16s 4s/step - loss: 0.6753 - accuracy: 0.8870 - val_loss: 2.5277 - val_accuracy: 0.7931
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.5752 - accuracy: 0.8957
# Epoch 10: val_loss did not improve from 1.80341
# 4/4 [==============================] - 15s 4s/step - loss: 0.5752 - accuracy: 0.8957 - val_loss: 1.8073 - val_accuracy: 0.8276
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.8870
# Epoch 11: val_loss improved from 1.80341 to 1.39418, saving model to results/cnn1/res0.h5
# 4/4 [==============================] - 20s 5s/step - loss: 0.6080 - accuracy: 0.8870 - val_loss: 1.3942 - val_accuracy: 0.8276
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.9652
# Epoch 12: val_loss did not improve from 1.39418
# 4/4 [==============================] - 15s 4s/step - loss: 0.1015 - accuracy: 0.9652 - val_loss: 2.5115 - val_accuracy: 0.6897
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.9478
# Epoch 13: val_loss improved from 1.39418 to 1.29183, saving model to results/cnn1/res0.h5
# 4/4 [==============================] - 19s 5s/step - loss: 0.3451 - accuracy: 0.9478 - val_loss: 1.2918 - val_accuracy: 0.8276
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9826
# Epoch 14: val_loss did not improve from 1.29183
# 4/4 [==============================] - 15s 4s/step - loss: 0.0504 - accuracy: 0.9826 - val_loss: 1.9122 - val_accuracy: 0.8276
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9739
# Epoch 15: val_loss did not improve from 1.29183
# 4/4 [==============================] - 15s 4s/step - loss: 0.0869 - accuracy: 0.9739 - val_loss: 1.4540 - val_accuracy: 0.7931
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9913
# Epoch 16: val_loss did not improve from 1.29183
# 4/4 [==============================] - 15s 4s/step - loss: 0.0372 - accuracy: 0.9913 - val_loss: 1.9737 - val_accuracy: 0.7586
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9913
# Epoch 17: val_loss did not improve from 1.29183
# 4/4 [==============================] - 15s 4s/step - loss: 0.0475 - accuracy: 0.9913 - val_loss: 1.9499 - val_accuracy: 0.7241
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 1.29183
# 4/4 [==============================] - 15s 4s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.5320 - val_accuracy: 0.8276
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 1.29183
# 4/4 [==============================] - 15s 4s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 1.4219 - val_accuracy: 0.8621
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 1.29183
# 4/4 [==============================] - 15s 4s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.4272 - val_accuracy: 0.8966
# 2/2 [==============================] - 1s 155ms/step - loss: 3.2486 - accuracy: 0.7778
# test_loss: 3.2486448287963867
# test_acc: 0.7777777910232544
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 13.2708 - accuracy: 0.4000
# Epoch 1: val_loss improved from inf to 1.70011, saving model to results/cnn1/res1.h5
# 4/4 [==============================] - 22s 5s/step - loss: 13.2708 - accuracy: 0.4000 - val_loss: 1.7001 - val_accuracy: 0.7241
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 1.6423 - accuracy: 0.6957
# Epoch 2: val_loss improved from 1.70011 to 1.33952, saving model to results/cnn1/res1.h5
# 4/4 [==============================] - 19s 5s/step - loss: 1.6423 - accuracy: 0.6957 - val_loss: 1.3395 - val_accuracy: 0.5517
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 1.0709 - accuracy: 0.6870
# Epoch 3: val_loss improved from 1.33952 to 1.13046, saving model to results/cnn1/res1.h5
# 4/4 [==============================] - 20s 5s/step - loss: 1.0709 - accuracy: 0.6870 - val_loss: 1.1305 - val_accuracy: 0.6207
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.7391
# Epoch 4: val_loss improved from 1.13046 to 0.67497, saving model to results/cnn1/res1.h5
# 4/4 [==============================] - 20s 5s/step - loss: 0.7443 - accuracy: 0.7391 - val_loss: 0.6750 - val_accuracy: 0.7241
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3619 - accuracy: 0.8522
# Epoch 5: val_loss did not improve from 0.67497
# 4/4 [==============================] - 17s 4s/step - loss: 0.3619 - accuracy: 0.8522 - val_loss: 0.7378 - val_accuracy: 0.8621
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8957
# Epoch 6: val_loss improved from 0.67497 to 0.49102, saving model to results/cnn1/res1.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.2716 - accuracy: 0.8957 - val_loss: 0.4910 - val_accuracy: 0.8621
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9304
# Epoch 7: val_loss did not improve from 0.49102
# 4/4 [==============================] - 19s 4s/step - loss: 0.1293 - accuracy: 0.9304 - val_loss: 0.4958 - val_accuracy: 0.7586
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9652
# Epoch 8: val_loss did not improve from 0.49102
# 4/4 [==============================] - 16s 4s/step - loss: 0.0864 - accuracy: 0.9652 - val_loss: 0.5350 - val_accuracy: 0.7931
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9739
# Epoch 9: val_loss did not improve from 0.49102
# 4/4 [==============================] - 15s 4s/step - loss: 0.0780 - accuracy: 0.9739 - val_loss: 0.4957 - val_accuracy: 0.7931
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 1.0000
# Epoch 10: val_loss improved from 0.49102 to 0.48687, saving model to results/cnn1/res1.h5
# 4/4 [==============================] - 21s 5s/step - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.4869 - val_accuracy: 0.8276
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.48687
# 4/4 [==============================] - 16s 4s/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.8276
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.48687
# 4/4 [==============================] - 16s 4s/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.5997 - val_accuracy: 0.7931
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.48687
# 4/4 [==============================] - 15s 4s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.6356 - val_accuracy: 0.7931
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.48687
# 4/4 [==============================] - 16s 4s/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.6261 - val_accuracy: 0.7931
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.48687
# 4/4 [==============================] - 15s 4s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.6342 - val_accuracy: 0.7931
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.48687
# 4/4 [==============================] - 15s 4s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.6521 - val_accuracy: 0.7931
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.48687
# 4/4 [==============================] - 15s 4s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.6632 - val_accuracy: 0.7931
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.48687
# 4/4 [==============================] - 15s 4s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.6565 - val_accuracy: 0.7931
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.48687
# 4/4 [==============================] - 15s 4s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.6583 - val_accuracy: 0.7931
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.48687
# 4/4 [==============================] - 15s 4s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.6639 - val_accuracy: 0.7931
# 2/2 [==============================] - 1s 127ms/step - loss: 1.0456 - accuracy: 0.7222
# test_loss: 1.045643925666809
# test_acc: 0.7222222089767456
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 12.0039 - accuracy: 0.4348
# Epoch 1: val_loss improved from inf to 7.63750, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 24s 6s/step - loss: 12.0039 - accuracy: 0.4348 - val_loss: 7.6375 - val_accuracy: 0.5862
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 8.7843 - accuracy: 0.5391
# Epoch 2: val_loss improved from 7.63750 to 2.49218, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 21s 5s/step - loss: 8.7843 - accuracy: 0.5391 - val_loss: 2.4922 - val_accuracy: 0.5862
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 3.1003 - accuracy: 0.6348
# Epoch 3: val_loss improved from 2.49218 to 1.39021, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 20s 5s/step - loss: 3.1003 - accuracy: 0.6348 - val_loss: 1.3902 - val_accuracy: 0.7931
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 2.0574 - accuracy: 0.7478
# Epoch 4: val_loss did not improve from 1.39021
# 4/4 [==============================] - 16s 4s/step - loss: 2.0574 - accuracy: 0.7478 - val_loss: 2.2378 - val_accuracy: 0.7586
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 1.6215 - accuracy: 0.8087
# Epoch 5: val_loss improved from 1.39021 to 1.08449, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 19s 5s/step - loss: 1.6215 - accuracy: 0.8087 - val_loss: 1.0845 - val_accuracy: 0.8276
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.8435
# Epoch 6: val_loss did not improve from 1.08449
# 4/4 [==============================] - 15s 4s/step - loss: 0.6291 - accuracy: 0.8435 - val_loss: 1.1034 - val_accuracy: 0.7241
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 0.5514 - accuracy: 0.7913
# Epoch 7: val_loss did not improve from 1.08449
# 4/4 [==============================] - 14s 4s/step - loss: 0.5514 - accuracy: 0.7913 - val_loss: 1.3827 - val_accuracy: 0.6897
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6455 - accuracy: 0.7652
# Epoch 8: val_loss improved from 1.08449 to 0.93655, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 20s 5s/step - loss: 0.6455 - accuracy: 0.7652 - val_loss: 0.9366 - val_accuracy: 0.7931
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4397 - accuracy: 0.7913
# Epoch 9: val_loss did not improve from 0.93655
# 4/4 [==============================] - 15s 4s/step - loss: 0.4397 - accuracy: 0.7913 - val_loss: 1.0918 - val_accuracy: 0.6207
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.4291 - accuracy: 0.8000
# Epoch 10: val_loss did not improve from 0.93655
# 4/4 [==============================] - 15s 4s/step - loss: 0.4291 - accuracy: 0.8000 - val_loss: 0.9803 - val_accuracy: 0.7241
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.8696
# Epoch 11: val_loss improved from 0.93655 to 0.82153, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 19s 5s/step - loss: 0.3183 - accuracy: 0.8696 - val_loss: 0.8215 - val_accuracy: 0.7931
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8522
# Epoch 12: val_loss improved from 0.82153 to 0.75537, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 18s 5s/step - loss: 0.3151 - accuracy: 0.8522 - val_loss: 0.7554 - val_accuracy: 0.7931
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9217
# Epoch 13: val_loss did not improve from 0.75537
# 4/4 [==============================] - 14s 4s/step - loss: 0.2137 - accuracy: 0.9217 - val_loss: 0.8346 - val_accuracy: 0.7931
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9130
# Epoch 14: val_loss improved from 0.75537 to 0.73147, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 20s 5s/step - loss: 0.1996 - accuracy: 0.9130 - val_loss: 0.7315 - val_accuracy: 0.8276
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9478
# Epoch 15: val_loss improved from 0.73147 to 0.71520, saving model to results/cnn1/res2.h5
# 4/4 [==============================] - 19s 5s/step - loss: 0.1626 - accuracy: 0.9478 - val_loss: 0.7152 - val_accuracy: 0.8621
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9478
# Epoch 16: val_loss did not improve from 0.71520
# 4/4 [==============================] - 15s 4s/step - loss: 0.1503 - accuracy: 0.9478 - val_loss: 0.7442 - val_accuracy: 0.8621
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9478
# Epoch 17: val_loss did not improve from 0.71520
# 4/4 [==============================] - 15s 4s/step - loss: 0.1403 - accuracy: 0.9478 - val_loss: 0.7946 - val_accuracy: 0.8621
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9478
# Epoch 18: val_loss did not improve from 0.71520
# 4/4 [==============================] - 15s 4s/step - loss: 0.1277 - accuracy: 0.9478 - val_loss: 0.7516 - val_accuracy: 0.8621
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1256 - accuracy: 0.9391
# Epoch 19: val_loss did not improve from 0.71520
# 4/4 [==============================] - 15s 4s/step - loss: 0.1256 - accuracy: 0.9391 - val_loss: 0.7587 - val_accuracy: 0.8621
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9391
# Epoch 20: val_loss did not improve from 0.71520
# 4/4 [==============================] - 15s 4s/step - loss: 0.1169 - accuracy: 0.9391 - val_loss: 0.7686 - val_accuracy: 0.8276
# 2/2 [==============================] - 1s 113ms/step - loss: 0.9770 - accuracy: 0.7222
# test_loss: 0.9770145416259766
# test_acc: 0.7222222089767456
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 29.7342 - accuracy: 0.2609
# Epoch 1: val_loss improved from inf to 24.65615, saving model to results/cnn1/res3.h5
# 4/4 [==============================] - 42s 10s/step - loss: 29.7342 - accuracy: 0.2609 - val_loss: 24.6562 - val_accuracy: 0.3793
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 15.3887 - accuracy: 0.5130
# Epoch 2: val_loss improved from 24.65615 to 6.53131, saving model to results/cnn1/res3.h5
# 4/4 [==============================] - 40s 10s/step - loss: 15.3887 - accuracy: 0.5130 - val_loss: 6.5313 - val_accuracy: 0.7241
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 5.3852 - accuracy: 0.6261
# Epoch 3: val_loss improved from 6.53131 to 1.29070, saving model to results/cnn1/res3.h5
# 4/4 [==============================] - 41s 10s/step - loss: 5.3852 - accuracy: 0.6261 - val_loss: 1.2907 - val_accuracy: 0.4828
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 1.6878 - accuracy: 0.4870
# Epoch 4: val_loss improved from 1.29070 to 0.73173, saving model to results/cnn1/res3.h5
# 4/4 [==============================] - 41s 10s/step - loss: 1.6878 - accuracy: 0.4870 - val_loss: 0.7317 - val_accuracy: 0.6897
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8835 - accuracy: 0.5391
# Epoch 5: val_loss did not improve from 0.73173
# 4/4 [==============================] - 36s 9s/step - loss: 0.8835 - accuracy: 0.5391 - val_loss: 0.8162 - val_accuracy: 0.5517
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 1.0186 - accuracy: 0.4435
# Epoch 6: val_loss did not improve from 0.73173
# 4/4 [==============================] - 38s 9s/step - loss: 1.0186 - accuracy: 0.4435 - val_loss: 0.9839 - val_accuracy: 0.3793
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 1.0070 - accuracy: 0.4609
# Epoch 7: val_loss did not improve from 0.73173
# 4/4 [==============================] - 38s 9s/step - loss: 1.0070 - accuracy: 0.4609 - val_loss: 0.9049 - val_accuracy: 0.4828
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 1.0012 - accuracy: 0.5130
# Epoch 8: val_loss did not improve from 0.73173
# 4/4 [==============================] - 35s 8s/step - loss: 1.0012 - accuracy: 0.5130 - val_loss: 0.8221 - val_accuracy: 0.5517
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.9443 - accuracy: 0.5391
# Epoch 9: val_loss did not improve from 0.73173
# 4/4 [==============================] - 33s 8s/step - loss: 0.9443 - accuracy: 0.5391 - val_loss: 0.7970 - val_accuracy: 0.5517
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.7570 - accuracy: 0.6696
# Epoch 10: val_loss improved from 0.73173 to 0.71120, saving model to results/cnn1/res3.h5
# 4/4 [==============================] - 37s 9s/step - loss: 0.7570 - accuracy: 0.6696 - val_loss: 0.7112 - val_accuracy: 0.6897
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.7826
# Epoch 11: val_loss did not improve from 0.71120
# 4/4 [==============================] - 33s 8s/step - loss: 0.6198 - accuracy: 0.7826 - val_loss: 0.9432 - val_accuracy: 0.7241
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6193 - accuracy: 0.7478
# Epoch 12: val_loss did not improve from 0.71120
# 4/4 [==============================] - 33s 8s/step - loss: 0.6193 - accuracy: 0.7478 - val_loss: 0.9725 - val_accuracy: 0.6897
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6252 - accuracy: 0.8087
# Epoch 13: val_loss did not improve from 0.71120
# 4/4 [==============================] - 35s 8s/step - loss: 0.6252 - accuracy: 0.8087 - val_loss: 1.0492 - val_accuracy: 0.7931
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.7391
# Epoch 14: val_loss did not improve from 0.71120
# 4/4 [==============================] - 33s 8s/step - loss: 0.6392 - accuracy: 0.7391 - val_loss: 1.0672 - val_accuracy: 0.5172
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8667 - accuracy: 0.6522
# Epoch 15: val_loss did not improve from 0.71120
# 4/4 [==============================] - 34s 8s/step - loss: 0.8667 - accuracy: 0.6522 - val_loss: 0.9645 - val_accuracy: 0.4138
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8614 - accuracy: 0.5739
# Epoch 16: val_loss did not improve from 0.71120
# 4/4 [==============================] - 34s 8s/step - loss: 0.8614 - accuracy: 0.5739 - val_loss: 0.9642 - val_accuracy: 0.3448
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8910 - accuracy: 0.5391
# Epoch 17: val_loss did not improve from 0.71120
# 4/4 [==============================] - 34s 8s/step - loss: 0.8910 - accuracy: 0.5391 - val_loss: 0.9928 - val_accuracy: 0.3448
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8880 - accuracy: 0.5391
# Epoch 18: val_loss did not improve from 0.71120
# 4/4 [==============================] - 34s 8s/step - loss: 0.8880 - accuracy: 0.5391 - val_loss: 0.9841 - val_accuracy: 0.3793
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8757 - accuracy: 0.5478
# Epoch 19: val_loss did not improve from 0.71120
# 4/4 [==============================] - 33s 8s/step - loss: 0.8757 - accuracy: 0.5478 - val_loss: 0.9830 - val_accuracy: 0.3103
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.8480 - accuracy: 0.5652
# Epoch 20: val_loss did not improve from 0.71120
# 4/4 [==============================] - 34s 8s/step - loss: 0.8480 - accuracy: 0.5652 - val_loss: 0.9880 - val_accuracy: 0.3793
# 2/2 [==============================] - 2s 200ms/step - loss: 1.3060 - accuracy: 0.3889
# test_loss: 1.30601966381073
# test_acc: 0.3888888955116272
# Epoch 1/20
# 4/4 [==============================] - ETA: 0s - loss: 12.5321 - accuracy: 0.4174
# Epoch 1: val_loss improved from inf to 8.87429, saving model to results/cnn1/res4.h5
# 4/4 [==============================] - 41s 10s/step - loss: 12.5321 - accuracy: 0.4174 - val_loss: 8.8743 - val_accuracy: 0.3793
# Epoch 2/20
# 4/4 [==============================] - ETA: 0s - loss: 7.2925 - accuracy: 0.5304
# Epoch 2: val_loss improved from 8.87429 to 7.39777, saving model to results/cnn1/res4.h5
# 4/4 [==============================] - 43s 11s/step - loss: 7.2925 - accuracy: 0.5304 - val_loss: 7.3978 - val_accuracy: 0.4828
# Epoch 3/20
# 4/4 [==============================] - ETA: 0s - loss: 6.2056 - accuracy: 0.5739
# Epoch 3: val_loss improved from 7.39777 to 2.63788, saving model to results/cnn1/res4.h5
# 4/4 [==============================] - 41s 10s/step - loss: 6.2056 - accuracy: 0.5739 - val_loss: 2.6379 - val_accuracy: 0.7241
# Epoch 4/20
# 4/4 [==============================] - ETA: 0s - loss: 2.3487 - accuracy: 0.7391
# Epoch 4: val_loss improved from 2.63788 to 1.74731, saving model to results/cnn1/res4.h5
# 4/4 [==============================] - 40s 10s/step - loss: 2.3487 - accuracy: 0.7391 - val_loss: 1.7473 - val_accuracy: 0.7241
# Epoch 5/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6720 - accuracy: 0.8000
# Epoch 5: val_loss improved from 1.74731 to 0.66355, saving model to results/cnn1/res4.h5
# 4/4 [==============================] - 39s 10s/step - loss: 0.6720 - accuracy: 0.8000 - val_loss: 0.6636 - val_accuracy: 0.8621
# Epoch 6/20
# 4/4 [==============================] - ETA: 0s - loss: 0.5679 - accuracy: 0.7913
# Epoch 6: val_loss did not improve from 0.66355
# 4/4 [==============================] - 35s 8s/step - loss: 0.5679 - accuracy: 0.7913 - val_loss: 1.0183 - val_accuracy: 0.7241
# Epoch 7/20
# 4/4 [==============================] - ETA: 0s - loss: 0.6402 - accuracy: 0.7826
# Epoch 7: val_loss did not improve from 0.66355
# 4/4 [==============================] - 32s 8s/step - loss: 0.6402 - accuracy: 0.7826 - val_loss: 0.8357 - val_accuracy: 0.6207
# Epoch 8/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3720 - accuracy: 0.7739
# Epoch 8: val_loss did not improve from 0.66355
# 4/4 [==============================] - 32s 8s/step - loss: 0.3720 - accuracy: 0.7739 - val_loss: 0.8953 - val_accuracy: 0.4828
# Epoch 9/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.8957
# Epoch 9: val_loss did not improve from 0.66355
# 4/4 [==============================] - 32s 8s/step - loss: 0.2514 - accuracy: 0.8957 - val_loss: 0.7641 - val_accuracy: 0.7586
# Epoch 10/20
# 4/4 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.9043
# Epoch 10: val_loss did not improve from 0.66355
# 4/4 [==============================] - 32s 8s/step - loss: 0.3050 - accuracy: 0.9043 - val_loss: 1.1723 - val_accuracy: 0.6897
# Epoch 11/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2756 - accuracy: 0.8783
# Epoch 11: val_loss did not improve from 0.66355
# 4/4 [==============================] - 32s 8s/step - loss: 0.2756 - accuracy: 0.8783 - val_loss: 1.3468 - val_accuracy: 0.7586
# Epoch 12/20
# 4/4 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.8957
# Epoch 12: val_loss did not improve from 0.66355
# 4/4 [==============================] - 33s 8s/step - loss: 0.2318 - accuracy: 0.8957 - val_loss: 1.2786 - val_accuracy: 0.7586
# Epoch 13/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9304
# Epoch 13: val_loss did not improve from 0.66355
# 4/4 [==============================] - 33s 8s/step - loss: 0.1685 - accuracy: 0.9304 - val_loss: 1.1339 - val_accuracy: 0.7586
# Epoch 14/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9304
# Epoch 14: val_loss did not improve from 0.66355
# 4/4 [==============================] - 36s 9s/step - loss: 0.1539 - accuracy: 0.9304 - val_loss: 1.0706 - val_accuracy: 0.7931
# Epoch 15/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9913
# Epoch 15: val_loss did not improve from 0.66355
# 4/4 [==============================] - 35s 8s/step - loss: 0.1204 - accuracy: 0.9913 - val_loss: 1.1205 - val_accuracy: 0.7586
# Epoch 16/20
# 4/4 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9913
# Epoch 16: val_loss did not improve from 0.66355
# 4/4 [==============================] - 36s 9s/step - loss: 0.1147 - accuracy: 0.9913 - val_loss: 1.0805 - val_accuracy: 0.7931
# Epoch 17/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9826
# Epoch 17: val_loss did not improve from 0.66355
# 4/4 [==============================] - 35s 8s/step - loss: 0.0936 - accuracy: 0.9826 - val_loss: 1.0405 - val_accuracy: 0.7931
# Epoch 18/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9826
# Epoch 18: val_loss did not improve from 0.66355
# 4/4 [==============================] - 34s 8s/step - loss: 0.0881 - accuracy: 0.9826 - val_loss: 1.0548 - val_accuracy: 0.7931
# Epoch 19/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9913
# Epoch 19: val_loss did not improve from 0.66355
# 4/4 [==============================] - 34s 8s/step - loss: 0.0791 - accuracy: 0.9913 - val_loss: 1.1044 - val_accuracy: 0.8276
# Epoch 20/20
# 4/4 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9913
# Epoch 20: val_loss did not improve from 0.66355
# 4/4 [==============================] - 35s 9s/step - loss: 0.0681 - accuracy: 0.9913 - val_loss: 1.0791 - val_accuracy: 0.8276
# 2/2 [==============================] - 2s 195ms/step - loss: 2.0167 - accuracy: 0.7778
# test_loss: 2.0166521072387695
# test_acc: 0.7777777910232544
# Epoch 1/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_8905/2009191908.py in <module>
#      41                 epochs=20,
#      42                 validation_data=(X_valid, y_valid),
# ---> 43                 callbacks=[checkpoint_cb]
#      44             )
#      45
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     978         # Lifting succeeded, so variables are initialized and we can run the
#     979         # stateless function.
# --> 980         return self._stateless_fn(*args, **kwds)
#     981     else:
#     982       _, _, filtered_flat_args = (
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:
